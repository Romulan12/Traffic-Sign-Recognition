# %% [markdown]
# <a href="https://colab.research.google.com/github/Romulan12/Traffic-Sign-Recognition/blob/master/Traffic_Signs_Test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import pickle
import pandas as pd
import cv2

# %%
from tensorflow.keras.models import load_model
import preprocessing

# %%
model_new = load_model('model.h5')

# %%
#predict internet number
import requests
from PIL import Image
url = 'https://c8.alamy.com/comp/A0RX23/cars-and-automobiles-must-turn-left-ahead-sign-A0RX23.jpg'
r = requests.get(url, stream=True)
img = Image.open(r.raw)
plt.imshow(img, cmap=plt.get_cmap('gray'))
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing.preprocess(img)
print(img.shape)
img = img.reshape(1, 32, 32, 1)
 
print("predicted sign: "+ str(model_new.predict_classes(img)))
# Out:
# (32, 32)
# predicted sign: [34]

# %%
url = 'https://previews.123rf.com/images/arducha/arducha1804/arducha180400118/101089191-a-road-warning-of-children-s-crossing-traffic-sign.jpg'
r = requests.get(url, stream=True)
img = Image.open(r.raw)
plt.imshow(img, cmap=plt.get_cmap('gray'))
 
img = np.asarray(img)
img = cv2.resize(img, (32, 32))
img = preprocessing.preprocess(img)
print(img.shape)
img = img.reshape(1, 32, 32, 1)
 
print("predicted sign: "+ str(model_new.predict_classes(img)))
# Out:
# (32, 32)
# predicted sign: [28]
